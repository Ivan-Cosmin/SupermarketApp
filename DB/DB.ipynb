-- %% [markdown]
-- # [SupermarketApp]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [SupermarketApp]    Script Date: 23.05.2024 13:15:00 ******/
CREATE DATABASE [SupermarketApp]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'SupermarketApp', FILENAME = N'D:\Programe\SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\SupermarketApp.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'SupermarketApp_log', FILENAME = N'D:\Programe\SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\SupermarketApp_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [SupermarketApp] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [SupermarketApp].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [SupermarketApp] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [SupermarketApp] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [SupermarketApp] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [SupermarketApp] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [SupermarketApp] SET ARITHABORT OFF 
GO
ALTER DATABASE [SupermarketApp] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [SupermarketApp] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [SupermarketApp] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [SupermarketApp] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [SupermarketApp] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [SupermarketApp] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [SupermarketApp] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [SupermarketApp] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [SupermarketApp] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [SupermarketApp] SET  DISABLE_BROKER 
GO
ALTER DATABASE [SupermarketApp] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [SupermarketApp] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [SupermarketApp] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [SupermarketApp] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [SupermarketApp] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [SupermarketApp] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [SupermarketApp] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [SupermarketApp] SET RECOVERY FULL 
GO
ALTER DATABASE [SupermarketApp] SET  MULTI_USER 
GO
ALTER DATABASE [SupermarketApp] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [SupermarketApp] SET DB_CHAINING OFF 
GO
ALTER DATABASE [SupermarketApp] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [SupermarketApp] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [SupermarketApp] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [SupermarketApp] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'SupermarketApp', N'ON'
GO
ALTER DATABASE [SupermarketApp] SET QUERY_STORE = ON
GO
ALTER DATABASE [SupermarketApp] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Categories]

-- %%
USE [SupermarketApp]
GO

-- %%
/****** Object:  Table [dbo].[Categories]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categories](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[Deleted] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Manufacturers]

-- %%
/****** Object:  Table [dbo].[Manufacturers]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Manufacturers](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[CountryOfOrigin] [varchar](100) NOT NULL,
	[Deleted] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Products]

-- %%
/****** Object:  Table [dbo].[Products]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Products](
	[Barcode] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[CategoryID] [int] NOT NULL,
	[ManufacturerID] [int] NOT NULL,
	[Deleted] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Barcode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProductsOnReceipts]

-- %%
/****** Object:  Table [dbo].[ProductsOnReceipts]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProductsOnReceipts](
	[ReceiptID] [int] NOT NULL,
	[StockID] [int] NOT NULL,
	[Quantity] [int] NOT NULL,
	[Subtotal] [decimal](10, 2) NOT NULL,
	[Deleted] [bit] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProductStocks]

-- %%
/****** Object:  Table [dbo].[ProductStocks]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProductStocks](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Barcode] [varchar](50) NOT NULL,
	[Quantity] [int] NOT NULL,
	[UnitOfMeasure] [varchar](50) NOT NULL,
	[SupplyDate] [date] NOT NULL,
	[ExpiryDate] [date] NOT NULL,
	[PurchasePrice] [decimal](10, 2) NOT NULL,
	[SellingPrice] [decimal](10, 2) NOT NULL,
	[Deleted] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Receipts]

-- %%
/****** Object:  Table [dbo].[Receipts]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Receipts](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[ReleaseDate] [date] NOT NULL,
	[CashierID] [int] NOT NULL,
	[TotalAmount] [decimal](10, 2) NOT NULL,
	[Deleted] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Username] [varchar](100) NOT NULL,
	[Password] [varchar](100) NOT NULL,
	[Type] [varchar](50) NOT NULL,
	[Deleted] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Categorie__Delet__11158940]

-- %%
ALTER TABLE [dbo].[Categories] ADD  DEFAULT ((0)) FOR [Deleted]
GO

-- %% [markdown]
-- # [DF__Manufactu__Delet__2057CCD0]

-- %%
ALTER TABLE [dbo].[Manufacturers] ADD  DEFAULT ((0)) FOR [Deleted]
GO

-- %% [markdown]
-- # [DF__Products__Delete__114A936A]

-- %%
ALTER TABLE [dbo].[Products] ADD  DEFAULT ((0)) FOR [Deleted]
GO

-- %% [markdown]
-- # [DF__ProductsO__Delet__5B78929E]

-- %%
ALTER TABLE [dbo].[ProductsOnReceipts] ADD  DEFAULT ((0)) FOR [Deleted]
GO

-- %% [markdown]
-- # [DF__Stocks__Deleted__5224328E]

-- %%
ALTER TABLE [dbo].[ProductStocks] ADD  DEFAULT ((0)) FOR [Deleted]
GO

-- %% [markdown]
-- # [DF__Receipts__Delete__1BC821DD]

-- %%
ALTER TABLE [dbo].[Receipts] ADD  DEFAULT ((0)) FOR [Deleted]
GO

-- %% [markdown]
-- # [DF__Users_New__Delet__756D6ECB]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT ((0)) FOR [Deleted]
GO

-- %% [markdown]
-- # [FK_Products_Categories]

-- %%
ALTER TABLE [dbo].[Products]  WITH CHECK ADD  CONSTRAINT [FK_Products_Categories] FOREIGN KEY([CategoryID])
REFERENCES [dbo].[Categories] ([ID])
GO
ALTER TABLE [dbo].[Products] CHECK CONSTRAINT [FK_Products_Categories]
GO

-- %% [markdown]
-- # [FK_Products_Manufacturers]

-- %%
ALTER TABLE [dbo].[Products]  WITH CHECK ADD  CONSTRAINT [FK_Products_Manufacturers] FOREIGN KEY([ManufacturerID])
REFERENCES [dbo].[Manufacturers] ([ID])
GO
ALTER TABLE [dbo].[Products] CHECK CONSTRAINT [FK_Products_Manufacturers]
GO

-- %% [markdown]
-- # [FK__ProductsO__Recei__59904A2C]

-- %%
ALTER TABLE [dbo].[ProductsOnReceipts]  WITH CHECK ADD FOREIGN KEY([ReceiptID])
REFERENCES [dbo].[Receipts] ([ID])
GO

-- %% [markdown]
-- # [FK__ProductsO__Stock__5A846E65]

-- %%
ALTER TABLE [dbo].[ProductsOnReceipts]  WITH CHECK ADD FOREIGN KEY([StockID])
REFERENCES [dbo].[ProductStocks] ([ID])
GO

-- %% [markdown]
-- # [FK__Stocks__Barcode__51300E55]

-- %%
ALTER TABLE [dbo].[ProductStocks]  WITH CHECK ADD FOREIGN KEY([Barcode])
REFERENCES [dbo].[Products] ([Barcode])
GO

-- %% [markdown]
-- # [FK_Receipts_CashierID]

-- %%
ALTER TABLE [dbo].[Receipts]  WITH CHECK ADD  CONSTRAINT [FK_Receipts_CashierID] FOREIGN KEY([CashierID])
REFERENCES [dbo].[Users] ([ID])
GO
ALTER TABLE [dbo].[Receipts] CHECK CONSTRAINT [FK_Receipts_CashierID]
GO

-- %% [markdown]
-- # [dbo].[ActivateCategory]

-- %%
/****** Object:  StoredProcedure [dbo].[ActivateCategory]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ActivateCategory]
    @Name VARCHAR(100)

AS
BEGIN
    -- Setăm Deleted = 1 pentru utilizatorul specificat
    UPDATE Categories
    SET Deleted = 0
    WHERE [Name] = @Name
	  AND Deleted = 1;
END;
GO

-- %% [markdown]
-- # [dbo].[ActivateManufacturer]

-- %%
/****** Object:  StoredProcedure [dbo].[ActivateManufacturer]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ActivateManufacturer]
    @Name VARCHAR(50),
    @CountryOfOrigin VARCHAR(50)
AS
BEGIN
    -- Setăm Deleted = 1 pentru utilizatorul specificat
    UPDATE Manufacturers
    SET Deleted = 0
    WHERE [Name] = @Name
	  AND CountryOfOrigin = @CountryOfOrigin
	  AND Deleted = 1;
END;
GO

-- %% [markdown]
-- # [dbo].[ActivateProduct]

-- %%
/****** Object:  StoredProcedure [dbo].[ActivateProduct]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ActivateProduct]
	@Barcode VARCHAR(100)
AS
BEGIN
    -- Setăm Deleted = 1 pentru utilizatorul specificat
    UPDATE Products
    SET Deleted = 0
    WHERE Barcode = @Barcode
	  AND Deleted = 1;
END;
GO

-- %% [markdown]
-- # [dbo].[ActivateUser]

-- %%
/****** Object:  StoredProcedure [dbo].[ActivateUser]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ActivateUser]
    @Username VARCHAR(100),
    @Password VARCHAR(100),
    @Type VARCHAR(50)

AS
BEGIN
    -- Setăm Deleted = 1 pentru utilizatorul specificat
    UPDATE Users
    SET Deleted = 0
    WHERE Username = @Username
      AND [Password] = @Password
      AND [Type] = @Type
	  AND Deleted = 1;
END;
GO

-- %% [markdown]
-- # [dbo].[AddCategory]

-- %%
/****** Object:  StoredProcedure [dbo].[AddCategory]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[AddCategory]
    @Name VARCHAR(50)
AS
BEGIN
    INSERT INTO Categories([Name])
    VALUES (@Name);
END
GO

-- %% [markdown]
-- # [dbo].[AddManufacturer]

-- %%
/****** Object:  StoredProcedure [dbo].[AddManufacturer]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[AddManufacturer]
    @Name VARCHAR(50),
    @CountryOfOrigin VARCHAR(50)
AS
BEGIN
    INSERT INTO Manufacturers([Name],CountryOfOrigin)
    VALUES (@Name,@CountryOfOrigin);
END
GO

-- %% [markdown]
-- # [dbo].[AddProduct]

-- %%
/****** Object:  StoredProcedure [dbo].[AddProduct]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[AddProduct]
    @Barcode VARCHAR(100),
    @Name VARCHAR(100),
    @CategoryName VARCHAR(50),
    @ManufacturerName VARCHAR(100),
    @ManufacturerCountryOfOrigin VARCHAR(100)
AS
BEGIN
    DECLARE @CategoryID INT;
    DECLARE @ManufacturerID INT;

    SELECT @CategoryID = ID
    FROM Categories
    WHERE Name = @CategoryName AND Deleted = 0;

    SELECT @ManufacturerID = ID
    FROM Manufacturers
    WHERE Name = @ManufacturerName AND CountryOfOrigin = @ManufacturerCountryOfOrigin AND Deleted = 0;


    INSERT INTO Products (Barcode, [Name], CategoryID, ManufacturerID)
    VALUES (@Barcode, @Name, @CategoryID, @ManufacturerID);
END;
GO

-- %% [markdown]
-- # [dbo].[AddProductStock]

-- %%
/****** Object:  StoredProcedure [dbo].[AddProductStock]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[AddProductStock]
    @Barcode VARCHAR(50),
    @Quantity INT,
    @UnitOfMeasure VARCHAR(50),
    @SupplyDate DATE,
    @ExpiryDate DATE,
    @PurchasePrice DECIMAL(10, 2),
    @SellingPrice DECIMAL(10, 2)
AS
BEGIN
    SET NOCOUNT ON

    INSERT INTO ProductStocks (Barcode, Quantity, UnitOfMeasure, SupplyDate, ExpiryDate, PurchasePrice, SellingPrice)
    VALUES (@Barcode, @Quantity, @UnitOfMeasure, @SupplyDate, @ExpiryDate, @PurchasePrice, @SellingPrice);
END
GO

-- %% [markdown]
-- # [dbo].[AddUser]

-- %%
/****** Object:  StoredProcedure [dbo].[AddUser]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[AddUser]
    @Username VARCHAR(50),
    @Password VARCHAR(50),
    @Type VARCHAR(50)
AS
BEGIN
    INSERT INTO Users (Username, [Password], [Type])
    VALUES (@Username, @Password, @Type);
END
GO

-- %% [markdown]
-- # [dbo].[CheckCategoryExists]

-- %%
/****** Object:  StoredProcedure [dbo].[CheckCategoryExists]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[CheckCategoryExists]
    @Name VARCHAR(100)
AS
BEGIN
    IF EXISTS (
        SELECT 1
        FROM Categories
        WHERE [Name] = @Name
    )
    BEGIN
        SELECT 1 AS CategoryExists;
    END
    ELSE
    BEGIN
        SELECT 0 AS CategoryExists;
    END
END;
GO

-- %% [markdown]
-- # [dbo].[CheckManufacturerExists]

-- %%
/****** Object:  StoredProcedure [dbo].[CheckManufacturerExists]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[CheckManufacturerExists]
    @Name VARCHAR(100),
	@CountryOfOrigin VARCHAR(100)
AS
BEGIN
    IF EXISTS (
        SELECT 1
        FROM Manufacturers
        WHERE [Name] = @Name
		AND CountryOfOrigin = @CountryOfOrigin
    )
    BEGIN
        SELECT 1 AS ManufacturerExists;
    END
    ELSE
    BEGIN
        SELECT 0 AS ManufacturerExists;
    END
END;
GO

-- %% [markdown]
-- # [dbo].[CheckProductExists]

-- %%
/****** Object:  StoredProcedure [dbo].[CheckProductExists]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[CheckProductExists]
	@Barcode VARCHAR(100)
AS
BEGIN
    -- Verificăm dacă există un utilizator cu Username și Type specificat
    IF EXISTS (
        SELECT 1
        FROM Products
        WHERE Barcode = @Barcode
    )
    BEGIN
        -- Dacă există, returnăm 1
        SELECT 1 AS ProductExists;
    END
    ELSE
    BEGIN
        -- Dacă nu există, returnăm 0
        SELECT 0 AS ProductExists;
    END
END;
GO

-- %% [markdown]
-- # [dbo].[CheckUserExists]

-- %%
/****** Object:  StoredProcedure [dbo].[CheckUserExists]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[CheckUserExists]
    @Username VARCHAR(100),
    @Type VARCHAR(50)
AS
BEGIN
    -- Verificăm dacă există un utilizator cu Username și Type specificat
    IF EXISTS (
        SELECT 1
        FROM Users
        WHERE Username = @Username
          AND Type = @Type
    )
    BEGIN
        -- Dacă există, returnăm 1
        SELECT 1 AS UserExists;
    END
    ELSE
    BEGIN
        -- Dacă nu există, returnăm 0
        SELECT 0 AS UserExists;
    END
END;
GO

-- %% [markdown]
-- # [dbo].[DeleteCategory]

-- %%
/****** Object:  StoredProcedure [dbo].[DeleteCategory]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[DeleteCategory]
    @Name VARCHAR(100)

AS
BEGIN
    UPDATE Categories
    SET Deleted = 1
    WHERE [Name] = @Name
	  AND Deleted = 0;
END;
GO

-- %% [markdown]
-- # [dbo].[DeleteManufacturer]

-- %%
/****** Object:  StoredProcedure [dbo].[DeleteManufacturer]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[DeleteManufacturer]
    @Name VARCHAR(50),
    @CountryOfOrigin VARCHAR(50)
AS
BEGIN
    -- Setăm Deleted = 1 pentru utilizatorul specificat
    UPDATE Manufacturers
    SET Deleted = 1
    WHERE [Name] = @Name
	  AND CountryOfOrigin = @CountryOfOrigin
	  AND Deleted = 0;
END;
GO

-- %% [markdown]
-- # [dbo].[DeleteProduct]

-- %%
/****** Object:  StoredProcedure [dbo].[DeleteProduct]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[DeleteProduct]
	@Barcode VARCHAR(100)
AS
BEGIN
    -- Setăm Deleted = 1 pentru utilizatorul specificat
    UPDATE Products
    SET Deleted = 1
    WHERE Barcode = @Barcode
	  AND Deleted = 0;
END;
GO

-- %% [markdown]
-- # [dbo].[DeleteUser]

-- %%
/****** Object:  StoredProcedure [dbo].[DeleteUser]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[DeleteUser]
    @Username VARCHAR(100),
    @Password VARCHAR(100),
    @Type VARCHAR(50)
AS
BEGIN
    -- Setăm Deleted = 1 pentru utilizatorul specificat
    UPDATE Users
    SET Deleted = 1
    WHERE Username = @Username
      AND [Password] = @Password
      AND [Type] = @Type
	  AND Deleted = 0;
END;
GO

-- %% [markdown]
-- # [dbo].[GetAllCategories]

-- %%
/****** Object:  StoredProcedure [dbo].[GetAllCategories]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[GetAllCategories]
AS
BEGIN
SELECT [Name],[Deleted]
FROM Categories
END
GO

-- %% [markdown]
-- # [dbo].[GetAllManufacturers]

-- %%
/****** Object:  StoredProcedure [dbo].[GetAllManufacturers]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[GetAllManufacturers]
AS
BEGIN
SELECT [Name],CountryOfOrigin,[Deleted]
FROM Manufacturers
END
GO

-- %% [markdown]
-- # [dbo].[GetAllProducts]

-- %%
/****** Object:  StoredProcedure [dbo].[GetAllProducts]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[GetAllProducts]
AS
BEGIN
    SELECT 
        p.Barcode,
        p.Name,
        c.Name AS CategoryName,
        m.Name AS ManufacturerName,
        m.CountryOfOrigin AS ManufacturerCountryOfOrigin,
        p.Deleted
    FROM 
        Products p
    INNER JOIN 
        Categories c ON p.CategoryID = c.ID
    INNER JOIN 
        Manufacturers m ON p.ManufacturerID = m.ID
    WHERE c.Deleted = 0
        AND m.Deleted = 0;
END;
GO

-- %% [markdown]
-- # [dbo].[GetAllProductStocks]

-- %%
/****** Object:  StoredProcedure [dbo].[GetAllProductStocks]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[GetAllProductStocks]
AS
BEGIN
    SET NOCOUNT ON;

    SELECT ps.ID, p.Name AS ProductName, p.Barcode, c.Name AS CategoryName, m.Name AS ManufacturerName,
           ps.Quantity, ps.UnitOfMeasure, ps.SupplyDate, ps.ExpiryDate, ps.PurchasePrice, ps.SellingPrice
    FROM ProductStocks ps
    INNER JOIN Products p ON ps.Barcode = p.Barcode
    INNER JOIN Categories c ON p.CategoryID = c.ID
    INNER JOIN Manufacturers m ON p.ManufacturerID = m.ID
    WHERE p.Deleted = 0 AND c.Deleted = 0 AND m.Deleted = 0;
END
GO

-- %% [markdown]
-- # [dbo].[GetAllUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[GetAllUsers]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[GetAllUsers]
AS
BEGIN
SELECT u.Username,u.[Password],u.[Type], u.Deleted
FROM Users u 
END
GO

-- %% [markdown]
-- # [dbo].[GetProductStockID]

-- %%
/****** Object:  StoredProcedure [dbo].[GetProductStockID]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[GetProductStockID]
    @Barcode VARCHAR(50),
    @PurchasePrice DECIMAL
AS
BEGIN
    -- Selectează StockID pe baza parametrilor furnizați
    SELECT ID
    FROM ProductStocks
    WHERE Barcode = @Barcode
      AND PurchasePrice = @PurchasePrice
END;
GO

-- %% [markdown]
-- # [dbo].[GetReceiptID]

-- %%
/****** Object:  StoredProcedure [dbo].[GetReceiptID]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[GetReceiptID]
    @CashierName VARCHAR(100),
    @Type VARCHAR(50),
    @Date DATE,
    @TotalPrice DECIMAL(10, 2)
AS
BEGIN
    DECLARE @CashierID INT;

    SELECT @CashierID = ID
    FROM Users
    WHERE Username = @CashierName
      AND Type = @Type
      AND Deleted = 0;

    SELECT ID
    FROM Receipts
    WHERE CashierID = @CashierID
      AND ReleaseDate = @Date
      AND TotalAmount = @TotalPrice;
END;
GO

-- %% [markdown]
-- # [dbo].[Login]

-- %%
/****** Object:  StoredProcedure [dbo].[Login]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[Login]
    @Username NVARCHAR(50),
    @Password NVARCHAR(50),
    @Type NVARCHAR(50)
AS
BEGIN
    SET NOCOUNT ON;

    SELECT ID
    FROM Users
    WHERE Username = @Username
      AND Password = @Password
      AND Type = @Type
	  AND Deleted = 0;
END
GO

-- %% [markdown]
-- # [dbo].[ModifyCategory]

-- %%
/****** Object:  StoredProcedure [dbo].[ModifyCategory]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ModifyCategory]
    @Name VARCHAR(100),
    @NewName VARCHAR(100)
AS
BEGIN
    UPDATE Categories
    SET 
        [Name] = @NewName
    WHERE 
        [Name] = @Name
END;
GO

-- %% [markdown]
-- # [dbo].[ModifyManufacturer]

-- %%
/****** Object:  StoredProcedure [dbo].[ModifyManufacturer]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ModifyManufacturer]
    @Name VARCHAR(100),
	@CountryOfOrigin VARCHAR(100),
    @NewName VARCHAR(100),
	@NewCountryOfOrigin VARCHAR(100)
AS
BEGIN
    UPDATE Manufacturers
    SET 
        [Name] = @NewName,
		[CountryOfOrigin] = @NewCountryOfOrigin

    WHERE[Name] = @Name
	AND [CountryOfOrigin] = @CountryOfOrigin
END;
GO

-- %% [markdown]
-- # [dbo].[ModifyProduct]

-- %%
/****** Object:  StoredProcedure [dbo].[ModifyProduct]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ModifyProduct]
    @Barcode VARCHAR(100),
    @NewBarcode VARCHAR(100),
    @NewName VARCHAR(100),
    @NewCategoryName VARCHAR(50),
    @NewManufacturerName VARCHAR(100),
    @NewManufacturerCountryOfOrigin VARCHAR(100)
AS
BEGIN
    -- Declarații pentru noile ID-uri
    DECLARE @CategoryID INT;
    DECLARE @ManufacturerID INT;

    -- Obținem CategoryID bazat pe noul nume de categorie
    SELECT @CategoryID = ID
    FROM Categories
    WHERE [Name] = @NewCategoryName AND Deleted = 0;

    -- Obținem ManufacturerID bazat pe noul nume de producător și țara de origine
    SELECT @ManufacturerID = ID
    FROM Manufacturers
    WHERE [Name] = @NewManufacturerName AND CountryOfOrigin = @NewManufacturerCountryOfOrigin AND Deleted = 0;
 
UPDATE Products
    SET 
        Barcode = @NewBarcode,
        Name = @NewName,
        CategoryID = @CategoryID,
        ManufacturerID = @ManufacturerID
    WHERE
        Barcode = @Barcode
END;
GO

-- %% [markdown]
-- # [dbo].[ModifyUser]

-- %%
/****** Object:  StoredProcedure [dbo].[ModifyUser]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ModifyUser]
    @Username VARCHAR(100),
    @Password VARCHAR(100),
    @Type VARCHAR(50),
    @NewUsername VARCHAR(100),
    @NewPassword VARCHAR(100),
    @NewType VARCHAR(50)
AS
BEGIN
    UPDATE Users
    SET 
        Username = @NewUsername,
        Password = @NewPassword,
        Type = @NewType
    WHERE 
        Username = @Username
        AND Password = @Password
        AND Type = @Type
END;
GO

-- %% [markdown]
-- # [dbo].[SearchProducts]

-- %%
/****** Object:  StoredProcedure [dbo].[SearchProducts]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SearchProducts]
    @Name VARCHAR(100) = NULL,
    @Barcode VARCHAR(100) = NULL,
    @ExpiryDate DATE = NULL,
    @ManufacturerName VARCHAR(100) = NULL,
    @CategoryName VARCHAR(50) = NULL
AS
BEGIN
    SELECT 
        p.Barcode,
        p.Name,
        s.ExpiryDate,
		s.Quantity AS Quantity,
		s.UnitOfMeasure AS UnitOfMeasure,
		s.SellingPrice AS SellingPrice,
        c.Name AS CategoryName,
        m.Name AS ManufacturerName,
        m.CountryOfOrigin AS ManufacturerCountryOfOrigin,
        p.Deleted
    FROM ProductStocks s
	JOIN
        Products p on p.Barcode = s.Barcode
    JOIN 
        Categories c ON p.CategoryID = c.ID
    JOIN 
        Manufacturers m ON p.ManufacturerID = m.ID
    WHERE 
        (@Name IS NULL OR p.Name LIKE '%' + @Name + '%') AND
        (@Barcode IS NULL OR p.Barcode LIKE '%' + @Barcode + '%') AND
        (@ExpiryDate IS NULL OR s.ExpiryDate = @ExpiryDate) AND
        (@ManufacturerName IS NULL OR m.Name LIKE '%' + @ManufacturerName + '%') AND
        (@CategoryName IS NULL OR c.Name LIKE '%' + @CategoryName + '%') AND
        p.Deleted = 0 AND
		c.Deleted = 0 AND
		s.Deleted = 0 AND
		m.Deleted = 0;
END;
GO

-- %% [markdown]
-- # [dbo].[UpdateStockQuantity]

-- %%
/****** Object:  StoredProcedure [dbo].[UpdateStockQuantity]    Script Date: 23.05.2024 13:15:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[UpdateStockQuantity]
    @StockID INT,
    @Quantity INT
AS
BEGIN
    -- Declarați o variabilă pentru a stoca cantitatea curentă
    DECLARE @CurrentQuantity INT;

    -- Obțineți cantitatea curentă din stoc
    SELECT @CurrentQuantity = Quantity
    FROM ProductStocks
    WHERE ID = @StockID;


    -- Actualizați cantitatea din stoc
    UPDATE ProductStocks
    SET Quantity = Quantity - @Quantity
    WHERE ID = @StockID;
END;
GO

-- %% [markdown]
-- # [SupermarketApp]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [SupermarketApp] SET  READ_WRITE 
GO
